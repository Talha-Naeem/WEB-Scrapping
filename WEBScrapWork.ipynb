# %% [markdown]
# # INTERACTING WITH WEB APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29678',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29678/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29678/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29678/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29678',
#   'id': 524038613,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODkwNDU1',
#   'number': 29678,
#   'title': 'DEPS: Unifying testing and building dependencies across builds',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2019-11-17T20:19:47Z',
#   'updated_at': '2019-11-18T09:08:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29678',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29678',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29678.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29678.patch'},
#   'body': "- [X] closes #29664\r\n\r\nIn our CI builds we're using different versions of pytest, pytest-xdist and other tools. Looks like Python 3.5 was forcing part of this, since some packages were not available.\r\n\r\nIn this PR I standardize the tools and versions we use in all packages, with only two exceptions:\r\n- In 32 bits we install `Cython` from pip instead of conda, since conda doesn't have the version we want\r\n- `pytest-azurepipelines` is installed only in builds currently running in pipelines\r\n\r\nI also reorganize a bit the builds so dependencies are easier to find. First is always Python, then the block with the tools, which is always the same with the exceptions mentioned above, and finally the dependencies."},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29676',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29676/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29676/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29676/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29676',
#   'id': 524021941,
#   'node_id': 'MDU6SXNzdWU1MjQwMjE5NDE=',
#   'number': 29676,
#   'title': 'CI: Clipboard Test Failures on Travis',
#   'user': {'login': 'alimcmaster1',
#    'id': 16733618,
#    'node_id': 'MDQ6VXNlcjE2NzMzNjE4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/16733618?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alimcmaster1',
#    'html_url': 'https://github.com/alimcmaster1',
#    'followers_url': 'https://api.github.com/users/alimcmaster1/followers',
#    'following_url': 'https://api.github.com/users/alimcmaster1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alimcmaster1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alimcmaster1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alimcmaster1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alimcmaster1/orgs',
#    'repos_url': 'https://api.github.com/users/alimcmaster1/repos',
#    'events_url': 'https://api.github.com/users/alimcmaster1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alimcmaster1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 76939933,
#     'node_id': 'MDU6TGFiZWw3NjkzOTkzMw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Unreliable%20Test',
#     'name': 'Unreliable Test',
#     'color': '5319e7',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-11-17T18:12:01Z',
#   'updated_at': '2019-11-17T18:12:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': '```\r\n[gw1] linux -- Python 3.6.6 /home/travis/miniconda3/envs/pandas-dev/bin/python\r\ndata = \'👍...\'\r\n    @pytest.mark.single\r\n    @pytest.mark.clipboard\r\n    @pytest.mark.skipif(not _DEPS_INSTALLED, reason="clipboard primitives not installed")\r\n    @pytest.mark.parametrize("data", ["\\U0001f44d...", "Ωœ∑´...", "abcd..."])\r\n    def test_raw_roundtrip(data):\r\n        # PR #25040 wide unicode wasn\'t copied correctly on PY3 on windows\r\n        clipboard_set(data)\r\n>       assert data == clipboard_get()\r\nE       AssertionError: assert \'👍...\' == \'\'\r\nE         - 👍...\r\npandas/tests/io/test_clipboard.py:264: AssertionError\r\n```\r\nExamples:\r\n\r\nhttps://travis-ci.org/pandas-dev/pandas/jobs/613141276?utm_medium=notification&utm_source=github_status\r\n\r\nhttps://travis-ci.org/pandas-dev/pandas/builds/613153224?utm_source=github_status&utm_medium=notification\r\n\r\nPotentially related change:\r\nhttps://github.com/pandas-dev/pandas/pull/28531'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29674',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29674/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29674/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29674/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29674',
#   'id': 524020443,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODc3ODgx',
#   'number': 29674,
#   'title': 'CI: Use bash for windows script on azure',
#   'user': {'login': 'alimcmaster1',
#    'id': 16733618,
#    'node_id': 'MDQ6VXNlcjE2NzMzNjE4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/16733618?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alimcmaster1',
#    'html_url': 'https://github.com/alimcmaster1',
#    'followers_url': 'https://api.github.com/users/alimcmaster1/followers',
#    'following_url': 'https://api.github.com/users/alimcmaster1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alimcmaster1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alimcmaster1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alimcmaster1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alimcmaster1/orgs',
#    'repos_url': 'https://api.github.com/users/alimcmaster1/repos',
#    'events_url': 'https://api.github.com/users/alimcmaster1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alimcmaster1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/16',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16/labels',
#    'id': 174211,
#    'node_id': 'MDk6TWlsZXN0b25lMTc0MjEx',
#    'number': 16,
#    'title': '1.0',
#    'description': '',
#    'creator': {'login': 'wesm',
#     'id': 329591,
#     'node_id': 'MDQ6VXNlcjMyOTU5MQ==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/329591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/wesm',
#     'html_url': 'https://github.com/wesm',
#     'followers_url': 'https://api.github.com/users/wesm/followers',
#     'following_url': 'https://api.github.com/users/wesm/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/wesm/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/wesm/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/wesm/subscriptions',
#     'organizations_url': 'https://api.github.com/users/wesm/orgs',
#     'repos_url': 'https://api.github.com/users/wesm/repos',
#     'events_url': 'https://api.github.com/users/wesm/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/wesm/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 135,
#    'closed_issues': 1091,
#    'state': 'open',
#    'created_at': '2012-09-13T02:13:00Z',
#    'updated_at': '2019-11-18T07:55:22Z',
#    'due_on': '2019-12-01T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2019-11-17T17:59:27Z',
#   'updated_at': '2019-11-18T02:08:04Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29674',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29674',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29674.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29674.patch'},
#   'body': '- Towards #26344\r\n- This makes `windows.yml` and `posix.yml` steps pretty similar and they could potentially be merged/reduce duplication? (Will leave this for a separate PR)\r\n- We also now use `ci/run_tests.sh` for windows test stage.\r\n\r\nReference https://github.com/pandas-dev/pandas/pull/27195 where I began this.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29672',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29672/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29672/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29672/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29672',
#   'id': 524010951,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODcxMjQ0',
#   'number': 29672,
#   'title': 'REF: align transform logic flow',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-11-17T16:40:28Z',
#   'updated_at': '2019-11-17T23:22:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29672',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29672',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29672.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29672.patch'},
#   'body': 'Implement SeriesGroupBy._transform_general to match DataFrameGroupBy._transform_general, re-arrange the checks within the two `transform` methods to be in the same order and be more linear.  Make the two _transform_fast methods have closer-to-matching signatures'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29671',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29671/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29671/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29671/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29671',
#   'id': 523997963,
#   'node_id': 'MDU6SXNzdWU1MjM5OTc5NjM=',
#   'number': 29671,
#   'title': 'CI: Speed up coverage tests by splitting files',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-11-17T15:02:55Z',
#   'updated_at': '2019-11-17T15:02:55Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'body': "In #28531 we started to parallelize tests in the CI by file. Meaning that each file in `pandas/tests/` will be assigned to a core, and will run fully there. Before, each individual test was assigned to a core. This makes things much simpler, since tests that cannot run in parallel just need to live in the same file. But it implies, that if a test file is big and contains many tests, it will slow down the running of all tests.\r\n\r\nAs an example, imagine we have 1,000 tests that take one second each, and we have 100 cores. 10 tests will be assigned to each core, and the test suite will run in 10 seconds using the 100 cores. But with the new set up, if we have a file with 100 tests, all them will run in a single core, and the test suite will take the 100 seconds that the core will need to run the 100 tests.\r\n\r\nIn practice, after #28531 most of the builds in the CI didn't increases much the time to run. Only the [coverage build](https://github.com/pandas-dev/pandas/blob/master/.travis.yml#L49) is in some cases taking significantly more (from around 30 minutes to around 45 minutes).\r\n\r\nThe solution to this is:\r\n- See how long each test file takes\r\n- Split the files taking longer in a meaningful way\r\n\r\nNote that tests can be skipped if dependencies are not found. For example, if matplotlib is not installed in the environment, the plotting tests will simply be skipped. So, it's needed to create an environment with the dependencies of the build `ci/deps/travis-36-cov.yaml`.\r\n\r\nTo call the exact tests as the build, see the call in [run_tests.sh](https://github.com/pandas-dev/pandas/blob/master/ci/run_tests.sh#L28), and replace the parameters by the ones defined in the [build](https://github.com/pandas-dev/pandas/blob/master/.travis.yml#L49)."},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29670',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29670/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29670/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29670/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29670',
#   'id': 523981370,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODUwMzkw',
#   'number': 29670,
#   'title': 'BUG: extra leading space in to_string when index=False',
#   'user': {'login': 'charlesdong1991',
#    'id': 9269816,
#    'node_id': 'MDQ6VXNlcjkyNjk4MTY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/9269816?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charlesdong1991',
#    'html_url': 'https://github.com/charlesdong1991',
#    'followers_url': 'https://api.github.com/users/charlesdong1991/followers',
#    'following_url': 'https://api.github.com/users/charlesdong1991/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/charlesdong1991/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/charlesdong1991/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/charlesdong1991/subscriptions',
#    'organizations_url': 'https://api.github.com/users/charlesdong1991/orgs',
#    'repos_url': 'https://api.github.com/users/charlesdong1991/repos',
#    'events_url': 'https://api.github.com/users/charlesdong1991/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/charlesdong1991/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13101118,
#     'node_id': 'MDU6TGFiZWwxMzEwMTExOA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Output-Formatting',
#     'name': 'Output-Formatting',
#     'color': 'ededed',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-11-17T12:51:05Z',
#   'updated_at': '2019-11-17T19:27:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29670',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29670',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29670.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29670.patch'},
#   'body': '- [x] closes #24980 , xref #28538\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\nI still see people posting issue for the change of behaviour in `to_string(index=False)` on pandas such as #28538 , so I think it might be worth it to reopen my previous stalled PR #25000 and see if could get it solved this time.\r\n\r\nAll the changes have been made based on the reviews in PR #25000 and for detailed summary and explanation, please check https://github.com/pandas-dev/pandas/pull/25000#issuecomment-458714951\r\nFeel free to take a look and any review and comments are very welcomed!'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29669',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29669/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29669/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29669/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29669',
#   'id': 523964428,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODM4OTgy',
#   'number': 29669,
#   'title': 'ENH: Add suffixes argument for pd.concat',
#   'user': {'login': 'charlesdong1991',
#    'id': 9269816,
#    'node_id': 'MDQ6VXNlcjkyNjk4MTY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/9269816?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charlesdong1991',
#    'html_url': 'https://github.com/charlesdong1991',
#    'followers_url': 'https://api.github.com/users/charlesdong1991/followers',
#    'following_url': 'https://api.github.com/users/charlesdong1991/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/charlesdong1991/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/charlesdong1991/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/charlesdong1991/subscriptions',
#    'organizations_url': 'https://api.github.com/users/charlesdong1991/orgs',
#    'repos_url': 'https://api.github.com/users/charlesdong1991/repos',
#    'events_url': 'https://api.github.com/users/charlesdong1991/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/charlesdong1991/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-11-17T10:15:30Z',
#   'updated_at': '2019-11-17T18:00:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29669',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29669',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29669.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29669.patch'},
#   'body': '- [x] closes #21791, xref #29615 \r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29668',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29668/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29668/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29668/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29668',
#   'id': 523956701,
#   'node_id': 'MDU6SXNzdWU1MjM5NTY3MDE=',
#   'number': 29668,
#   'title': 'parameter "na_values" in read_excel() not effective when reading #DIV/0!',
#   'user': {'login': 'scienceunivers',
#    'id': 57838591,
#    'node_id': 'MDQ6VXNlcjU3ODM4NTkx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/57838591?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scienceunivers',
#    'html_url': 'https://github.com/scienceunivers',
#    'followers_url': 'https://api.github.com/users/scienceunivers/followers',
#    'following_url': 'https://api.github.com/users/scienceunivers/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/scienceunivers/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/scienceunivers/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/scienceunivers/subscriptions',
#    'organizations_url': 'https://api.github.com/users/scienceunivers/orgs',
#    'repos_url': 'https://api.github.com/users/scienceunivers/repos',
#    'events_url': 'https://api.github.com/users/scienceunivers/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/scienceunivers/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-11-17T08:58:17Z',
#   'updated_at': '2019-11-17T08:58:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nnaValues = ''\r\ntestdf = pd.read_excel('read_excel_bug.xlsx',\r\n                        sheet_name=0,header=0, names=None, index_col=None, \r\n                        usecols=None, squeeze=False, dtype=None, engine=None, \r\n                        converters=None, true_values=None, false_values=None,\r\n                       skiprows=None, nrows=None, \r\n                        na_values=naValues, keep_default_na=False, verbose=False, \r\n                        parse_dates=False, date_parser=None, thousands=None, comment=None, \r\n                        skip_footer=0, skipfooter=0, convert_float=True, mangle_dupe_cols=True)\r\ntestdf\r\n\r\n```\r\n#### Problem description\r\nI set the na_values param to None, and make keep_default_na=False, according to the doc, after execution cells of the “数据” column should be #DIV/0!, but in fact they are all NaN.\r\n\r\n\r\n index   |机构\t|全称\t|社会信用代码\t|账号|\t数据\r\n-----|-----|---------|----------------|--------|------\r\n0\t|机构1|\t机构1的全称|\t9.144030e+17\t|alading\t|NaN\r\n1\t|NaN\t|NaN\t|NaN\t|NaN\t|NaN\r\n\r\n\r\n#### Expected Output\r\n index   |机构\t|全称\t|社会信用代码\t|账号|\t数据\r\n-----|-----|---------|----------------|--------|------\r\n0\t|机构1|\t机构1的全称|\t9.144030e+17\t|alading\t|#DIV/0!\r\n1\t|NaN\t|NaN\t|NaN\t|NaN\t|#DIV/0!\r\n\r\n[read_excel_bug.xlsx](https://github.com/pandas-dev/pandas/files/3855400/read_excel_bug.xlsx)\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : None\r\npython           : 3.6.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.None\r\n\r\npandas           : 0.25.2\r\nnumpy            : 1.14.2\r\npytz             : 2017.3\r\ndateutil         : 2.6.1\r\npip              : 19.0.3\r\nsetuptools       : 38.4.0\r\nCython           : 0.27.3\r\npytest           : 3.3.2\r\nhypothesis       : None\r\nsphinx           : 1.6.6\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.0.2\r\nlxml.etree       : 4.1.1\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.10\r\nIPython          : 6.2.1\r\npandas_datareader: None\r\nbs4              : 4.6.0\r\nbottleneck       : 1.2.1\r\nfastparquet      : None\r\ngcsfs            : None\r\nlxml.etree       : 4.1.1\r\nmatplotlib       : 2.1.2\r\nnumexpr          : 2.6.4\r\nodfpy            : None\r\nopenpyxl         : 2.4.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npytables         : None\r\ns3fs             : None\r\nscipy            : 1.0.0\r\nsqlalchemy       : 1.2.1\r\ntables           : 3.4.2\r\nxarray           : None\r\nxlrd             : 1.1.0\r\nxlwt             : 1.3.0\r\nxlsxwriter       : 1.0.2\r\n\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29666',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29666/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29666/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29666/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29666',
#   'id': 523930794,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODE2NjU3',
#   'number': 29666,
#   'title': 'Extension Module Compat Cleanup',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False},
#    {'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/16',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16/labels',
#    'id': 174211,
#    'node_id': 'MDk6TWlsZXN0b25lMTc0MjEx',
#    'number': 16,
#    'title': '1.0',
#    'description': '',
#    'creator': {'login': 'wesm',
#     'id': 329591,
#     'node_id': 'MDQ6VXNlcjMyOTU5MQ==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/329591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/wesm',
#     'html_url': 'https://github.com/wesm',
#     'followers_url': 'https://api.github.com/users/wesm/followers',
#     'following_url': 'https://api.github.com/users/wesm/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/wesm/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/wesm/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/wesm/subscriptions',
#     'organizations_url': 'https://api.github.com/users/wesm/orgs',
#     'repos_url': 'https://api.github.com/users/wesm/repos',
#     'events_url': 'https://api.github.com/users/wesm/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/wesm/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 135,
#    'closed_issues': 1091,
#    'state': 'open',
#    'created_at': '2012-09-13T02:13:00Z',
#    'updated_at': '2019-11-18T07:55:22Z',
#    'due_on': '2019-12-01T08:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2019-11-17T03:46:26Z',
#   'updated_at': '2019-11-18T02:04:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29666',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29666',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29666.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29666.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] passes `black pandas`\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29664',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29664/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29664/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29664/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29664',
#   'id': 523927802,
#   'node_id': 'MDU6SXNzdWU1MjM5Mjc4MDI=',
#   'number': 29664,
#   'title': 'CI: Unify pytest versions across builds',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2019-11-17T03:04:04Z',
#   'updated_at': '2019-11-17T17:55:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'body': "May be I'm missing something, but is there a reason to use different pytest versions in our CI builds? I see we're using those in the dependencies files:\r\n- pytest\r\n- pytest>=4.0.2\r\n- pytest>=4.0.2,<5.0\r\n- pytest=4.5.0\r\n- pytest>=5.0.0\r\n- pytest>=5.0.1\r\n\r\nSince pytest is not a pandas dependency, but just a tool we use, feels like we should just use always the same version (the latest). All those (all versions since pytest 4) support Python >3.6, so I don't think there is any limitation that prevents this.\r\n\r\nAm I missing something? Can we always use the same version?\r\n\r\nI'm thinking on having a separate file for the tools needed for all builds (pytest, pytest-xdist...), and install both dependency files, the one of the build, and the common one. So we don't have to duplicate those in every file (it's faster to maintain and make changes, and also easier to see what dependencies we have and what we're testing in every build).\r\n\r\n@jreback @TomAugspurger does this make sense?"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29657',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29657/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29657/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29657/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29657',
#   'id': 523817690,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxNzM2Nzc3',
#   'number': 29657,
#   'title': 'BUG: resolved problem with DataFrame.equals() (#28839)',
#   'user': {'login': 'Reksbril',
#    'id': 29033769,
#    'node_id': 'MDQ6VXNlcjI5MDMzNzY5',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/29033769?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Reksbril',
#    'html_url': 'https://github.com/Reksbril',
#    'followers_url': 'https://api.github.com/users/Reksbril/followers',
#    'following_url': 'https://api.github.com/users/Reksbril/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Reksbril/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Reksbril/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Reksbril/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Reksbril/orgs',
#    'repos_url': 'https://api.github.com/users/Reksbril/repos',
#    'events_url': 'https://api.github.com/users/Reksbril/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Reksbril/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/16',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16/labels',
#    'id': 174211,
#    'node_id': 'MDk6TWlsZXN0b25lMTc0MjEx',
#    'number': 16,
#    'title': '1.0',
#    'description': '',
#    'creator': {'login': 'wesm',
#     'id': 329591,
#     'node_id': 'MDQ6VXNlcjMyOTU5MQ==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/329591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/wesm',
#     'html_url': 'https://github.com/wesm',
#     'followers_url': 'https://api.github.com/users/wesm/followers',
#     'following_url': 'https://api.github.com/users/wesm/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/wesm/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/wesm/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/wesm/subscriptions',
#     'organizations_url': 'https://api.github.com/users/wesm/orgs',
#     'repos_url': 'https://api.github.com/users/wesm/repos',
#     'events_url': 'https://api.github.com/users/wesm/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/wesm/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 135,
#    'closed_issues': 1091,
#    'state': 'open',
#    'created_at': '2012-09-13T02:13:00Z',
#    'updated_at': '2019-11-18T07:55:22Z',
#    'due_on': '2019-12-01T08:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2019-11-16T08:47:17Z',
#   'updated_at': '2019-11-16T21:26:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29657',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29657',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/29657.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/29657.patch'},
#   'body': 'The function was returning True in case shown in added test. The cause\r\nof the problem was sorting Blocks of DataFrame by type, and then\r\nmgr_locs before comparison. It resulted in arranging the identical blocks\r\nin the same way, which resulted in having the same two lists of blocks.\r\nChanging sorting order to (mgr_locs, type) resolves the problem, while not\r\ninterrupting the other aspects of comparison.\r\n\r\n- [x] closes #28839\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29654',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29654/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29654/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29654/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29654',
#   'id': 523779950,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxNzE0OTcw',
#   'number': 29654,
#   'title': 'CI: Format isort output for azure',
#   'user': {'login': 'alimcmaster1',
#    'id': 16733618,
#    'node_id': 'MDQ6VXNlcjE2NzMzNjE4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/16733618?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alimcmaster1',
#    'html_url': 'https://github.com/alimcmaster1',
#    'followers_url': 'https://api.github.com/users/alimcmaster1/followers',
#    'following_url': 'https://api.github.com/users/alimcmaster1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alimcmaster1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alimcmaster1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alimcmaster1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alimcmaster1/orgs',
#    'repos_url': 'https://api.github.com/users/alimcmaster1/repos',
#    'events_url': 'https://api.github.com/users/alimcmaster1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alimcmaster1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 42670965,
#     'node_id': 'MDU6TGFiZWw0MjY3MDk2NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting',
#     'name': 'Error Reporting',
#     'color': 'ffa0ff',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/16',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/16/labels',
#    'id': 174211,
#    'node_id': 'MDk6TWlsZXN0b25lMTc0MjEx',
#    'number': 16,
#    'title': '1.0',
#    'description': '',
#    'creator': {'login': 'wesm',
#     'id': 329591,
#     'node_id': 'MDQ6VXNlcjMyOTU5MQ==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/329591?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/wesm',
#     'html_url': 'https://github.com/wesm',
#     'followers_url': 'https://api.github.com/users/wesm/followers',
#     'following_url': 'https://api.github.com/users/wesm/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/wesm/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/wesm/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/wesm/subscriptions',
#     'organizations_url': 'https://api.github.com/users/wesm/orgs',
#     'repos_url': 'https://api.github.com/users/wesm/repos',
#     'events_url': 'https://api.github.com/users/wesm/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/wesm/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 135,
#    'closed_issues': 1091,
#    'state': 'open',
#    'created_at': '2012-09-13T02:13:00Z',
#    'updated_at': '2019-11-18T07:55:22Z',
#    'due_on': '2019-12-01T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2019-11-16T02:59:26Z',
#   'updated_at': '2019-11-17T15:58:28Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/29654',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/29654',
# ...
#    'events_url': 'https://api.github.com/users/alimcmaster1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alimcmaster1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-11-14T20:58:53Z',
#   'updated_at': '2019-11-15T15:10:39Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': '`test_thousands_macau_index_col` in `test_html` fails using beautifulsoup4 version 4.8.1 and passes using version 4.7.1.\r\n\r\nExample failures:\r\nhttps://travis-ci.org/pandas-dev/pandas/jobs/611742966\r\n\r\nAs pointed out by @jreback in this PR - https://github.com/pandas-dev/pandas/pull/29603\r\n\r\nExample failing build pre my changes in #29513\r\nhttps://travis-ci.org/pandas-dev/pandas/jobs/611347428\r\n\r\nAttempting to debug issue and will report to bs4. Should we pin in the meantime to version <= 4.7.1? \r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29618',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29618/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29618/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29618/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29618',
#   'id': 522946244,
#   'node_id': 'MDU6SXNzdWU1MjI5NDYyNDQ=',
#   'number': 29618,
#   'title': "Int64 can't be used in pandas.eval()",
#   'user': {'login': 'antonov-andrey',
#    'id': 13316422,
#    'node_id': 'MDQ6VXNlcjEzMzE2NDIy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/13316422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antonov-andrey',
#    'html_url': 'https://github.com/antonov-andrey',
#    'followers_url': 'https://api.github.com/users/antonov-andrey/followers',
#    'following_url': 'https://api.github.com/users/antonov-andrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/antonov-andrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/antonov-andrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/antonov-andrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/antonov-andrey/orgs',
#    'repos_url': 'https://api.github.com/users/antonov-andrey/repos',
#    'events_url': 'https://api.github.com/users/antonov-andrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/antonov-andrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-11-14T15:51:32Z',
#   'updated_at': '2019-11-15T07:46:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': 'This code works fine\r\n```python\r\nimport pandas as pd\r\n\r\nd = pd.DataFrame([[1, 2], [3, 4]], columns=[\'a\', \'b\'], dtype="Float64")\r\nd.eval(\'c = b - a\', inplace=True)\r\n```\r\n\r\n### This code fails with the following stacktrace below\r\n```python\r\nd = pd.DataFrame([[1, 2], [3, 4]], columns=[\'a\', \'b\'], dtype="Int64")\r\nd.eval(\'c = b - a\', inplace=True)\r\n```\r\n\r\n```text\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n<ipython-input-43-42645933ba81> in <module>\r\n----> 1 d.eval(\'c = b - a\', inplace=True)\r\n      2 d\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)\r\n   3313             kwargs["target"] = self\r\n   3314         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)\r\n-> 3315         return _eval(expr, inplace=inplace, **kwargs)\r\n   3316 \r\n   3317     def select_dtypes(self, include=None, exclude=None):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)\r\n    320         )\r\n    321 \r\n--> 322         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env, truediv=truediv)\r\n    323 \r\n    324         # construct the engine and evaluate the parsed expression\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, truediv, level)\r\n    828         self.env.scope["truediv"] = truediv\r\n    829         self._visitor = _parsers[parser](self.env, self.engine, self.parser)\r\n--> 830         self.terms = self.parse()\r\n    831 \r\n    832     @property\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in parse(self)\r\n    845     def parse(self):\r\n    846         """Parse an expression"""\r\n--> 847         return self._visitor.visit(self.expr)\r\n    848 \r\n    849     @property\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)\r\n    439         method = "visit_" + node.__class__.__name__\r\n    440         visitor = getattr(self, method)\r\n--> 441         return visitor(node, **kwargs)\r\n    442 \r\n    443     def visit_Module(self, node, **kwargs):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)\r\n    445             raise SyntaxError("only a single expression is allowed")\r\n    446         expr = node.body[0]\r\n--> 447         return self.visit(expr, **kwargs)\r\n    448 \r\n    449     def visit_Expr(self, node, **kwargs):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)\r\n    439         method = "visit_" + node.__class__.__name__\r\n    440         visitor = getattr(self, method)\r\n--> 441         return visitor(node, **kwargs)\r\n    442 \r\n    443     def visit_Module(self, node, **kwargs):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Assign(self, node, **kwargs)\r\n    663             )\r\n    664 \r\n--> 665         return self.visit(node.value, **kwargs)\r\n    666 \r\n    667     def visit_Attribute(self, node, **kwargs):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)\r\n    439         method = "visit_" + node.__class__.__name__\r\n    440         visitor = getattr(self, method)\r\n--> 441         return visitor(node, **kwargs)\r\n    442 \r\n    443     def visit_Module(self, node, **kwargs):\r\n\r\n~/.local/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)\r\n    563         op, op_class, left, right = self._maybe_transform_eq_ne(node)\r\n    564         left, right = self._maybe_downcast_constants(left, right)\r\n ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29617',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29617/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29617/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29617/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29617',
#   'id': 522914887,
#   'node_id': 'MDU6SXNzdWU1MjI5MTQ4ODc=',
#   'number': 29617,
#   'title': 'BUG: groupby apply with head(1) raises keyerror with datetime grouper',
#   'user': {'login': 'endremborza',
#    'id': 11783247,
#    'node_id': 'MDQ6VXNlcjExNzgzMjQ3',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/11783247?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/endremborza',
#    'html_url': 'https://github.com/endremborza',
#    'followers_url': 'https://api.github.com/users/endremborza/followers',
#    'following_url': 'https://api.github.com/users/endremborza/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/endremborza/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/endremborza/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/endremborza/subscriptions',
#    'organizations_url': 'https://api.github.com/users/endremborza/orgs',
#    'repos_url': 'https://api.github.com/users/endremborza/repos',
#    'events_url': 'https://api.github.com/users/endremborza/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/endremborza/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-11-14T15:01:34Z',
#   'updated_at': '2019-11-16T13:34:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': 'This is a very strange error with a long traceback. I found #15680 and #11324 mentioning similar things, but neither seem to cover the behavior here\r\n\r\n#### Code Sample, a copy-pastable example:\r\n\r\n```python\r\nimport datetime\r\nimport pandas as pd\r\n\r\nrecs = [{\'LIVE\': 1,\r\n         \'ITEM\': \'001\',\r\n         \'DATE\': datetime.date(2019, 10, 1)},\r\n        {\'LIVE\': 2,\r\n         \'ITEM\': \'002\',\r\n         \'DATE\': datetime.date(2019, 10, 2)},\r\n        {\'LIVE\': 3,\r\n         \'ITEM\': \'003\',\r\n         \'DATE\': datetime.date(2019, 10, 1)}]\r\n\r\npd.DataFrame(recs).groupby([\'ITEM\', \'DATE\']).apply(lambda df: df.head(1))\r\n```\r\n\r\non 0.25.3 this raises this convoluted KeyError:\r\n\r\n<details>\r\n\r\n```\r\n---------------------------------------------------------------------------\r\nKeyError                                  Traceback (most recent call last)\r\n~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)\r\n   2896             try:\r\n-> 2897                 return self._engine.get_loc(key)\r\n   2898             except KeyError:\r\n\r\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\r\n\r\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\r\n\r\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\r\n\r\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\r\n\r\nKeyError: Timestamp(\'2019-10-01 00:00:00\')\r\n\r\nDuring handling of the above exception, another exception occurred:\r\n\r\nKeyError                                  Traceback (most recent call last)\r\n~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _make_concat_multiindex(indexes, keys, levels, names)\r\n    631                 try:\r\n--> 632                     i = level.get_loc(key)\r\n    633                 except KeyError:\r\n\r\n~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)\r\n   2898             except KeyError:\r\n-> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))\r\n   2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)\r\n\r\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\r\n\r\npandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()\r\n\r\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\r\n\r\npandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()\r\n\r\nKeyError: Timestamp(\'2019-10-01 00:00:00\')\r\n\r\nDuring handling of the above exception, another exception occurred:\r\n\r\nValueError                                Traceback (most recent call last)\r\n~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)\r\n    724             try:\r\n--> 725                 result = self._python_apply_general(f)\r\n    726             except Exception:\r\n\r\n~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)\r\n    744         return self._wrap_applied_output(\r\n--> 745             keys, values, not_indexed_same=mutated or self.mutated\r\n    746         )\r\n\r\n~/.local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _wrap_applied_output(self, keys, values, not_indexed_same)\r\n    371         elif isinstance(v, DataFrame):\r\n--> 372             return self._concat_objects(keys, values, not_indexed_same=not_indexed_same)\r\n    373         elif self.grouper.groupings is not None:\r\n\r\n~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _concat_objects(self, keys, values, not_indexed_same)\r\n    972                     names=group_names,\r\n--> 973                     sort=False,\r\n    974                 )\r\n\r\n~/.local/lib/p ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29612',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29612/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29612/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29612/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29612',
#   'id': 522628416,
#   'node_id': 'MDU6SXNzdWU1MjI2Mjg0MTY=',
#   'number': 29612,
#   'title': 'Line plot is not displaying correctly using pandas',
#   'user': {'login': 'Ashutosh341',
#    'id': 54778459,
#    'node_id': 'MDQ6VXNlcjU0Nzc4NDU5',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/54778459?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ashutosh341',
#    'html_url': 'https://github.com/Ashutosh341',
#    'followers_url': 'https://api.github.com/users/Ashutosh341/followers',
#    'following_url': 'https://api.github.com/users/Ashutosh341/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Ashutosh341/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Ashutosh341/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Ashutosh341/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Ashutosh341/orgs',
#    'repos_url': 'https://api.github.com/users/Ashutosh341/repos',
#    'events_url': 'https://api.github.com/users/Ashutosh341/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Ashutosh341/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-11-14T05:10:00Z',
#   'updated_at': '2019-11-14T09:04:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': 'I have installed latest pandas version\r\n\r\nNow I am trying to plot a bar plot by using pandas but it is giving me this Figure\r\n\r\n![Capture line plot](https://user-images.githubusercontent.com/54778459/68828240-07f75980-06cb-11ea-8c50-5c2ffd53cb9b.PNG)\r\n.png)\r\n\r\nI am learning pandas from Udemy and when trainer was plotting bar plot , it was plotting correctly\r\n![Capture112](https://user-images.githubusercontent.com/54778459/68828495-e2b71b00-06cb-11ea-8704-9e6cb45eae26.PNG)\r\n '}]

# %%
data[0]['title']
# Out:
# 'DEPS: Unifying testing and building dependencies across builds'

# %%
import pandas as pd

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues.head()
# Out:
#    number                                              title  \
# 0   29678  DEPS: Unifying testing and building dependenci...
# 1   29676              CI: Clipboard Test Failures on Travis
# 2   29674           CI: Use bash for windows script on azure
# 3   29672                    REF: align transform logic flow
# 4   29671     CI: Speed up coverage tests by splitting files
#
#                                               labels state
# 0  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 1  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 2  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 3  [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNj...  open
# 4  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open

# %% [markdown]
# # INTERACTING WITH DATABASE

# %%
import sqlite3

# %%
query = """
CREATE TABLE test
(a VARCHAR(20),b VARCHAR(20), c REAL,d INTEGER);"""
con = sqlite3.connect("mydata.sqlite")
con.execute(query)
con.commit()

# %%
data = [('tal','fi',2,1),
       ('ft','tf',1,2),
       ('ia','ai',5,7)]

# %%
stm = "INSERT INTO TEST VALUES(?,?,?,?)"
con.executemany(stm,data)
con.commit()

# %%
cursor = con.execute("select * from test")
rows = cursor.fetchall()
rows
# Out:
# [('tal', 'fi', 2.0, 1), ('ft', 'tf', 1.0, 2), ('ia', 'ai', 5.0, 7)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows,columns=[x[0] for x in cursor.description])
# Out:
#      a   b    c  d
# 0  tal  fi  2.0  1
# 1   ft  tf  1.0  2
# 2   ia  ai  5.0  7

# %%
import sqlalchemy as sqla

# %%
db = sqla.create_engine("sqlite:///mydata.sqlite")
pd.read_sql("select * from test",db)
# Out:
#      a   b    c  d
# 0  tal  fi  2.0  1
# 1   ft  tf  1.0  2
# 2   ia  ai  5.0  7
